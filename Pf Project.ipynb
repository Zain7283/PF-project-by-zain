# %%
import pandas as pd

# %%
df=pd.read_csv("top universities.csv")

# %%
df
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# ...

# %%
df.dropna()
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# ...

# %%
df.dropna(inplace=True)

# %%
df.fillna(999)
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# ...

# %%
df.head()
# Out:
#                                           University  Country     City  \
# 0  Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1           Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2          École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                      École Nationale Polytechnique  Algeria  Algiers
# 4       Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
#
#    Global Rank
# 0         3677
# 1         4919
# 2         6297
# 3         6411
# 4         6421

# %%
df["Country"].fillna(879)
# Out:
# 0        Algeria
# 1        Algeria
# 2        Algeria
# 3        Algeria
# 4        Algeria
#           ...
# 12708    Uruguay
# 12709    Uruguay
# 12710    Uruguay
# 12711    Uruguay
# 12712    Uruguay
# Name: Country, Length: 12713, dtype: object

# %%
df.tail()
# Out:
#                                               University  Country     City  \
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 12708        11518
# 12709        11549
# 12710        11572
# 12711        11630
# 12712        12698

# %%
df.sample()
# Out:
#                                 University Country  \
# 8041  Uniwersytet Ekonomiczny we Wroclawiu  Poland
#
#                             City  Global Rank
# 8041  Lower Silesian Voivodeship         2770

# %%
df.describe()
# Out:
#         Global Rank
# count  12713.000000
# mean    6369.518760
# std     3665.469943
# min        1.000000
# 25%     3199.000000
# 50%     6373.000000
# 75%     9540.000000
# max    12721.000000

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12708    False
# 12709    False
# 12710    False
# 12711    False
# 12712    False
# Length: 12713, dtype: bool

# %%
print(df.shape)
# Out:
# (12713, 4)

# %%
df.rename(columns={"Global Rank":"Global"})
#is used in pandas to rename coloumns in the dataframe df.
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global
# 0        3677
# 1        4919
# 2        6297
# ...

# %%
pd.set_option=("display.max_rows",None)
df
#this will display all rows when u print or display the dataframe (df in this case) By default pandas limits the number of rows shown to avoid overwhelming the output.
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12713 entries, 0 to 12712
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   University   12713 non-null  object
#  1   Country      12713 non-null  object
#  2   City         12713 non-null  object
#  3   Global Rank  12713 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 397.4+ KB

# %%
df.describe()
# Out:
#         Global Rank
# count  12713.000000
# mean    6369.518760
# std     3665.469943
# min        1.000000
# 25%     3199.000000
# 50%     6373.000000
# 75%     9540.000000
# max    12721.000000

# %%
df.describe(include = "all")
# Out:
#                   University Country      City   Global Rank
# count                  12713   12713     12713  12713.000000
# unique                 12528     145      1157           NaN
# top     Holy City University     Usa  New York           NaN
# freq                       2    1724       150           NaN
# mean                     NaN     NaN       NaN   6369.518760
# std                      NaN     NaN       NaN   3665.469943
# min                      NaN     NaN       NaN      1.000000
# 25%                      NaN     NaN       NaN   3199.000000
# 50%                      NaN     NaN       NaN   6373.000000
# 75%                      NaN     NaN       NaN   9540.000000
# max                      NaN     NaN       NaN  12721.000000

# %%
a=df["City"]
a
# Out:
# 0        Algiers
# 1        Algiers
# 2        Algiers
# 3        Algiers
# 4        Algiers
#           ...
# 12708    Uruguay
# 12709    Uruguay
# 12710    Uruguay
# 12711    Uruguay
# 12712    Uruguay
# Name: City, Length: 12713, dtype: object

# %%
b= df[["City","Global Rank"]]
b
# Out:
#           City  Global Rank
# 0      Algiers         3677
# 1      Algiers         4919
# 2      Algiers         6297
# 3      Algiers         6411
# 4      Algiers         6421
# ...        ...          ...
# 12708  Uruguay        11518
# 12709  Uruguay        11549
# 12710  Uruguay        11572
# 12711  Uruguay        11630
# 12712  Uruguay        12698
#
# [12713 rows x 2 columns]

# %%
df["Global Rank"].mean()
# Out:
# np.float64(6369.518760324077)

# %%
df["Global Rank"].median
# Out:
# <bound method Series.median of 0         3677
# 1         4919
# 2         6297
# 3         6411
# 4         6421
#          ...
# 12708    11518
# 12709    11549
# 12710    11572
# 12711    11630
# 12712    12698
# Name: Global Rank, Length: 12713, dtype: int64>

# %%
df["Global Rank"].mode
# Out:
# <bound method Series.mode of 0         3677
# 1         4919
# 2         6297
# 3         6411
# 4         6421
#          ...
# 12708    11518
# 12709    11549
# 12710    11572
# 12711    11630
# 12712    12698
# Name: Global Rank, Length: 12713, dtype: int64>

# %%
df["City"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Algiers
# 1        Algiers
# 2        Algiers
# 3        Algiers
# 4        Algiers
#           ...
# 12708    Uruguay
# 12709    Uruguay
# 12710    Uruguay
# 12711    Uruguay
# 12712    Uruguay
# Name: City, Length: 12713, dtype: object>

# %%
df["Country"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df["Global Rank"].plot(kind="line")
# Out:
# <Axes: >

# %%
df["Country"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Country"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Country"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Country'>

# %%
df["Country"].value_counts().plot(kind="line",color="blue")
# Out:
# <Axes: xlabel='Country'>

# %%
df.plot(color="red")
# Out:
# <Axes: >

# %%
df["Global Rank"].std()
# Out:
# np.float64(3665.469942896735)

# %%
df.isnull().sum()
# Out:
# University     0
# Country        0
# City           0
# Global Rank    0
# dtype: int64

# %%
df[df["Global Rank"].isnull()]
# Out:
# Empty DataFrame
# Columns: [University, Country, City, Global Rank]
# Index: []

# %%
df.columns
# Out:
# Index(['University', 'Country', 'City', 'Global Rank'], dtype='object')
